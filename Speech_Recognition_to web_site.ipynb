# %%
# !pip install SpeechRecognition
# !pip install pyttsx3
# Out:
# Requirement already satisfied: SpeechRecognition in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (3.14.3)
# Requirement already satisfied: typing-extensions in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from SpeechRecognition) (4.15.0)
# Requirement already satisfied: pyttsx3 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (2.99)
# Requirement already satisfied: comtypes in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from pyttsx3) (1.4.13)
# Requirement already satisfied: pypiwin32 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from pyttsx3) (223)
# Requirement already satisfied: pywin32 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from pyttsx3) (311)

# %%
import speech_recognition
import pyttsx3
import webbrowser

# %%
if __name__ == "__main__":
    path = "C:/Program Files (x86)/Microsoft/Edge/Application/msedge.exe %s"

    sr = speech_recognition.Recognizer()

    with speech_recognition.Microphone()as source:
        sr.adjust_for_ambient_noise(source)
        print("Please say something to openn")

        audio = sr.listen(source)
        print("Hearing")

        try:
            destination = sr.recognize_google(audio)
            print("you asked to open: "+destination)
            webbrowser.get(path).open(destination)

        except Exception as e:
            print("error :" +str(e))
# Out:
# Please say something to openn
# Hearing
# you asked to open: www.youtube.com
